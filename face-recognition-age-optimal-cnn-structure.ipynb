# %% [markdown]
# <a href="https://www.kaggle.com/code/artemsilvander/face-recognition-age-optimal-cnn-structure?scriptVersionId=119481647" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/age-gender-and-ethnicity-face-data-csv/age_gender.csv

# %% [markdown]
# # Base model

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from keras.models import Sequential
from keras.layers import Conv2D, Dropout, BatchNormalization, Flatten, Dense, MaxPooling2D
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam

from sklearn.metrics import mean_absolute_error, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../input/age-gender-and-ethnicity-face-data-csv/age_gender.csv')
df.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels
# 0  129 128 128 126 127 130 133 135 139 142 145 14...
# 1  164 74 111 168 169 171 175 182 184 188 193 199...
# 2  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3  193 197 198 200 199 200 202 203 204 205 208 21...
# 4  202 205 209 210 209 209 210 211 212 214 218 21...

# %%
df['pixels'] = df['pixels'].map(lambda x: np.array(x.split(' '), dtype=np.float32).reshape(48, 48))

# %%
# Reshape images for CNN
X = np.array(df['pixels'].to_list())
X_reshaped = X.reshape(X.shape[0], 48, 48, 1)
# Normalise images
if np.max(X_reshaped) > 1: X_reshaped = X_reshaped / 255
# Set some useful variables
input_shape = X_reshaped.shape[1:] 

# Set y
y = df['age'].values

# %%
# Train test split
X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y, test_size=0.2, random_state=123)

# %%
age_model_1 = Sequential()

age_model_1.add(Conv2D(64, kernel_size=(3,3), input_shape=input_shape, activation='relu'))
age_model_1.add(MaxPooling2D(pool_size=(2,2)))
age_model_1.add(BatchNormalization())

age_model_1.add(Conv2D(128, kernel_size=(3,3), activation='relu', padding='same'))
age_model_1.add(Conv2D(128, kernel_size=(3,3), activation='relu'))
age_model_1.add(MaxPooling2D(pool_size=(2,2)))
age_model_1.add(Dropout(0.3))
age_model_1.add(BatchNormalization())

age_model_1.add(Conv2D(256, kernel_size=(3,3), activation='relu', padding='same'))
age_model_1.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
age_model_1.add(MaxPooling2D(pool_size=(2,2)))
age_model_1.add(Dropout(0.3))
age_model_1.add(BatchNormalization())

age_model_1.add(Conv2D(512, kernel_size=(3,3), activation='relu', padding='same'))
age_model_1.add(MaxPooling2D(pool_size=(2,2)))
age_model_1.add(Dropout(0.5))
age_model_1.add(BatchNormalization())

age_model_1.add(Flatten())
age_model_1.add(Dense(128, activation='relu'))
age_model_1.add(Dropout(0.4))
age_model_1.add(Dense(1))

age_model_1.compile(optimizer='adam', loss='mean_absolute_error')

age_model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 23, 23, 64)       0
#  )
#
#  batch_normalization (BatchN  (None, 23, 23, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 23, 23, 128)       73856
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  dropout (Dropout)           (None, 10, 10, 128)       0
#
#  batch_normalization_1 (Batc  (None, 10, 10, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 256)       295168
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         590080
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 4, 4, 256)         0
#
#  batch_normalization_2 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 512)         1180160
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 512)         0
#
#  batch_normalization_3 (Batc  (None, 2, 2, 512)        2048
#  hNormalization)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 2,553,729
# Trainable params: 2,551,809
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
# Callbacks for age model
callbacks = [EarlyStopping(patience=10, 
                               min_delta=0.001,
                               restore_best_weights=True),
             ReduceLROnPlateau(patience = 2,
                               verbose=1,
                               factor=0.5,
                               min_lr = 0.0001)]

# %%
history = age_model_1.fit(X_train, y_train, 
                        epochs=20,
                        batch_size=64,
                        callbacks=callbacks,
                        validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 297/297 [==============================] - 11s 17ms/step - loss: 11.1776 - val_loss: 31.8221 - lr: 0.0010
# Epoch 2/20
# 297/297 [==============================] - 4s 15ms/step - loss: 8.6845 - val_loss: 32.6355 - lr: 0.0010
# Epoch 3/20
# 297/297 [==============================] - 4s 15ms/step - loss: 8.1333 - val_loss: 12.6871 - lr: 0.0010
# Epoch 4/20
# 297/297 [==============================] - 4s 15ms/step - loss: 7.7850 - val_loss: 10.8982 - lr: 0.0010
# Epoch 5/20
# 297/297 [==============================] - 5s 16ms/step - loss: 7.4877 - val_loss: 8.3220 - lr: 0.0010
# Epoch 6/20
# 297/297 [==============================] - 5s 16ms/step - loss: 7.2297 - val_loss: 10.2687 - lr: 0.0010
# Epoch 7/20
# 293/297 [============================>.] - ETA: 0s - loss: 7.0710
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 297/297 [==============================] - 4s 15ms/step - loss: 7.0729 - val_loss: 8.7802 - lr: 0.0010
# Epoch 8/20
# 297/297 [==============================] - 5s 16ms/step - loss: 6.5142 - val_loss: 6.5197 - lr: 5.0000e-04
# Epoch 9/20
# 297/297 [==============================] - 4s 15ms/step - loss: 6.3673 - val_loss: 6.1607 - lr: 5.0000e-04
# Epoch 10/20
# 297/297 [==============================] - 5s 16ms/step - loss: 6.1553 - val_loss: 9.0009 - lr: 5.0000e-04
# Epoch 11/20
# 293/297 [============================>.] - ETA: 0s - loss: 6.1394
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 297/297 [==============================] - 5s 16ms/step - loss: 6.1378 - val_loss: 8.1884 - lr: 5.0000e-04
# Epoch 12/20
# 297/297 [==============================] - 4s 15ms/step - loss: 5.7638 - val_loss: 5.8109 - lr: 2.5000e-04
# Epoch 13/20
# 297/297 [==============================] - 4s 15ms/step - loss: 5.6823 - val_loss: 9.1629 - lr: 2.5000e-04
# Epoch 14/20
# 293/297 [============================>.] - ETA: 0s - loss: 5.5366
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 297/297 [==============================] - 5s 16ms/step - loss: 5.5439 - val_loss: 5.9899 - lr: 2.5000e-04
# Epoch 15/20
# 297/297 [==============================] - 4s 15ms/step - loss: 5.4110 - val_loss: 6.1155 - lr: 1.2500e-04
# Epoch 16/20
# 293/297 [============================>.] - ETA: 0s - loss: 5.2881
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001.
# 297/297 [==============================] - 4s 15ms/step - loss: 5.2811 - val_loss: 7.1935 - lr: 1.2500e-04
# Epoch 17/20
# 297/297 [==============================] - 5s 16ms/step - loss: 5.2444 - val_loss: 6.8135 - lr: 1.0000e-04
# Epoch 18/20
# 297/297 [==============================] - 5s 16ms/step - loss: 5.2265 - val_loss: 5.4794 - lr: 1.0000e-04
# Epoch 19/20
# 297/297 [==============================] - 5s 16ms/step - loss: 5.0943 - val_loss: 5.5520 - lr: 1.0000e-04
# Epoch 20/20
# 297/297 [==============================] - 5s 16ms/step - loss: 5.0302 - val_loss: 5.4967 - lr: 1.0000e-04

# %%
pd.DataFrame(history.history).plot();

# %%
valid_score = age_model_1.evaluate(X_test, y_test, verbose=1)
# Out:
# 149/149 [==============================] - 1s 4ms/step - loss: 5.4967

# %%
# Make predictions 
y_pred = age_model_1.predict(X_test)
# Out:
# 149/149 [==============================] - 1s 3ms/step

# %%
# Man absolute error
print("MAE: {}".format(mean_absolute_error(y_test, y_pred)))
# Out:
# MAE: 5.496736936165899

# %%
from sklearn.metrics import r2_score

# calculate R2 score
r2 = r2_score(y_test, y_pred)

print("R2 score: {:.3f}".format(r2))
# Out:
# R2 score: 0.844

# %%
import matplotlib.pyplot as plt

def face_prediction(image):
    
    x = image.reshape(1, 48, 48, 1)
    x = x / 255
    
    age_predict = int(age_model_1.predict(x))
    
    plt.imshow(image)
    plt.title("Predicted Age: %d" % age_predict)
    plt.axis('off')

# %%
# Final check
random_face = np.random.choice(len(df))

age = df['age'][random_face]

plt.imshow(df['pixels'][random_face])
plt.title('Age: {0}'.format(age))
plt.axis('off')
# Out:
# (-0.5, 47.5, 47.5, -0.5)

# %%
# Model prediction 
face_prediction(df['pixels'][random_face])
# Out:
# 1/1 [==============================] - 0s 54ms/step

# %% [markdown]
# # Model Modifications

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from keras.models import Sequential
from keras.layers import Conv2D, Dropout, BatchNormalization, Flatten, Dense, MaxPooling2D
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam

from sklearn.metrics import mean_absolute_error, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../input/age-gender-and-ethnicity-face-data-csv/age_gender.csv')
df['pixels'] = df['pixels'].map(lambda x: np.array(x.split(' '), dtype=np.float32).reshape(48, 48))

# %%
# Reshape images for CNN
X = np.array(df['pixels'].to_list())
X_reshaped = X.reshape(X.shape[0], 48, 48, 1)
# Normalise images
if np.max(X_reshaped) > 1: X_reshaped = X_reshaped / 255
# Set some useful variables
input_shape = X_reshaped.shape[1:] 

# Set y
y = df['age'].values

# %%
# Train test split
X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y, test_size=0.2, random_state=123)

# %% [markdown]
# # 1. Simple model

# %%
age_model_1 = Sequential()

age_model_1.add(Conv2D(32, kernel_size=(3,3), input_shape=input_shape, activation='relu'))
age_model_1.add(MaxPooling2D(pool_size=(2,2)))

age_model_1.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
age_model_1.add(MaxPooling2D(pool_size=(2,2)))

age_model_1.add(Conv2D(128, kernel_size=(3,3), activation='relu'))
age_model_1.add(MaxPooling2D(pool_size=(2,2)))

age_model_1.add(Flatten())
age_model_1.add(Dense(256, activation='relu'))
age_model_1.add(Dropout(0.5))
age_model_1.add(Dense(1, activation='linear'))

age_model_1.compile(optimizer='adam', loss='mean_absolute_error')

age_model_1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 46, 46, 32)        320
#
#  max_pooling2d_4 (MaxPooling  (None, 23, 23, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 21, 21, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_6 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 256)               524544
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 617,473
# Trainable params: 617,473
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Callbacks for age model
callbacks = [EarlyStopping(patience=10, 
                               min_delta=0.001,
                               restore_best_weights=True),
             ReduceLROnPlateau(patience = 2,
                               verbose=1,
                               factor=0.5,
                               min_lr = 0.0001)]

# %%
history = age_model_1.fit(X_train, y_train, 
                        epochs=35,
                        batch_size=64,
                        callbacks=callbacks,
                        validation_data=(X_test, y_test))
# Out:
# Epoch 1/35
# 297/297 [==============================] - 2s 6ms/step - loss: 15.8965 - val_loss: 14.2506 - lr: 0.0010
# Epoch 2/35
# 297/297 [==============================] - 2s 6ms/step - loss: 13.2342 - val_loss: 12.7573 - lr: 0.0010
# Epoch 3/35
# 297/297 [==============================] - 2s 6ms/step - loss: 11.4970 - val_loss: 11.1349 - lr: 0.0010
# Epoch 4/35
# 297/297 [==============================] - 2s 6ms/step - loss: 10.8368 - val_loss: 10.3616 - lr: 0.0010
# Epoch 5/35
# 297/297 [==============================] - 2s 5ms/step - loss: 10.1248 - val_loss: 9.8687 - lr: 0.0010
# Epoch 6/35
# 297/297 [==============================] - 2s 6ms/step - loss: 9.5749 - val_loss: 8.9455 - lr: 0.0010
# Epoch 7/35
# 297/297 [==============================] - 2s 6ms/step - loss: 9.1850 - val_loss: 8.5345 - lr: 0.0010
# Epoch 8/35
# 297/297 [==============================] - 2s 5ms/step - loss: 9.0929 - val_loss: 8.3138 - lr: 0.0010
# Epoch 9/35
# 297/297 [==============================] - 2s 5ms/step - loss: 8.5732 - val_loss: 8.0295 - lr: 0.0010
# Epoch 10/35
# 297/297 [==============================] - 2s 6ms/step - loss: 8.2407 - val_loss: 7.8762 - lr: 0.0010
# Epoch 11/35
# 297/297 [==============================] - 2s 5ms/step - loss: 8.1030 - val_loss: 7.6704 - lr: 0.0010
# Epoch 12/35
# 297/297 [==============================] - 2s 6ms/step - loss: 7.9556 - val_loss: 7.5264 - lr: 0.0010
# Epoch 13/35
# 297/297 [==============================] - 2s 6ms/step - loss: 7.8570 - val_loss: 7.5102 - lr: 0.0010
# Epoch 14/35
# 297/297 [==============================] - 2s 5ms/step - loss: 7.5892 - val_loss: 8.4842 - lr: 0.0010
# Epoch 15/35
# 297/297 [==============================] - 2s 6ms/step - loss: 7.6268 - val_loss: 7.4132 - lr: 0.0010
# Epoch 16/35
# 297/297 [==============================] - 2s 6ms/step - loss: 7.3721 - val_loss: 7.1062 - lr: 0.0010
# Epoch 17/35
# 297/297 [==============================] - 2s 6ms/step - loss: 7.2533 - val_loss: 7.3419 - lr: 0.0010
# Epoch 18/35
# 291/297 [============================>.] - ETA: 0s - loss: 7.1471
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 297/297 [==============================] - 2s 6ms/step - loss: 7.1412 - val_loss: 7.2711 - lr: 0.0010
# Epoch 19/35
# 297/297 [==============================] - 2s 7ms/step - loss: 6.7707 - val_loss: 6.9329 - lr: 5.0000e-04
# Epoch 20/35
# 297/297 [==============================] - 2s 6ms/step - loss: 6.6522 - val_loss: 7.3401 - lr: 5.0000e-04
# Epoch 21/35
# 297/297 [==============================] - 2s 5ms/step - loss: 6.5794 - val_loss: 6.8524 - lr: 5.0000e-04
# Epoch 22/35
# 297/297 [==============================] - 2s 5ms/step - loss: 6.5711 - val_loss: 6.9733 - lr: 5.0000e-04
# Epoch 23/35
# 297/297 [==============================] - 2s 6ms/step - loss: 6.5309 - val_loss: 6.8147 - lr: 5.0000e-04
# Epoch 24/35
# 297/297 [==============================] - 2s 6ms/step - loss: 6.3716 - val_loss: 6.8582 - lr: 5.0000e-04
# Epoch 25/35
# 288/297 [============================>.] - ETA: 0s - loss: 6.3564
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 297/297 [==============================] - 2s 6ms/step - loss: 6.3496 - val_loss: 6.8274 - lr: 5.0000e-04
# Epoch 26/35
# 297/297 [==============================] - 2s 5ms/step - loss: 6.1471 - val_loss: 6.7894 - lr: 2.5000e-04
# Epoch 27/35
# 297/297 [==============================] - 2s 6ms/step - loss: 6.1035 - val_loss: 6.7672 - lr: 2.5000e-04
# Epoch 28/35
# 297/297 [==============================] - 2s 5ms/step - loss: 6.0332 - val_loss: 6.7560 - lr: 2.5000e-04
# Epoch 29/35
# 297/297 [==============================] - 2s 6ms/step - loss: 6.0265 - val_loss: 6.8829 - lr: 2.5000e-04
# Epoch 30/35
# 297/297 [==============================] - 2s 6ms/step - loss: 5.9362 - val_loss: 6.7241 - lr: 2.5000e-04
# Epoch 31/35
# 297/297 [==============================] - 2s 6ms/step - loss: 5.9946 - val_loss: 7.0319 - lr: 2.5000e-04
# Epoch 32/35
# 297/297 [==============================] - ETA: 0s - loss: 5.9448
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 297/297 [==============================] - 2s 6ms/step - loss: 5.9448 - val_loss: 6.8203 - lr: 2.5000e-04
# Epoch 33/35
# 297/297 [==============================] - 2s 6ms/step - loss: 5.7979 - val_loss: 6.8035 - lr: 1.2500e-04
# Epoch 34/35
# 287/297 [===========================>..] - ETA: 0s - loss: 5.7714
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0001.
# 297/297 [==============================] - 2s 5ms/step - loss: 5.7765 - val_loss: 6.8395 - lr: 1.2500e-04
# Epoch 35/35
# 297/297 [==============================] - 2s 6ms/step - loss: 5.7513 - val_loss: 6.6916 - lr: 1.0000e-04

# %%
pd.DataFrame(history.history).plot();

# %%
from sklearn.metrics import r2_score

# Make predictions 
y_pred = age_model_1.predict(X_test)

# calculate R2 score
r2 = r2_score(y_test, y_pred)

print("R2 score: {:.3f}".format(r2))
# Out:
# 149/149 [==============================] - 0s 2ms/step
# R2 score: 0.782

# %% [markdown]
# # 2. Complex model

# %%
age_model_2 = Sequential()

# First convolutional block
age_model_2.add(Conv2D(64, kernel_size=(3,3), input_shape=input_shape, activation='relu'))
age_model_2.add(MaxPooling2D(pool_size=(2,2)))
age_model_2.add(BatchNormalization())

# Second convolutional block
age_model_2.add(Conv2D(128, kernel_size=(3,3), activation='relu', padding='same'))
age_model_2.add(Conv2D(128, kernel_size=(3,3), activation='relu'))
age_model_2.add(MaxPooling2D(pool_size=(2,2)))
age_model_2.add(Dropout(0.3))
age_model_2.add(BatchNormalization())

# Third convolutional block
age_model_2.add(Conv2D(256, kernel_size=(3,3), activation='relu', padding='same'))
age_model_2.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
age_model_2.add(MaxPooling2D(pool_size=(2,2)))
age_model_2.add(Dropout(0.3))
age_model_2.add(BatchNormalization())

# Fourth convolutional block
age_model_2.add(Conv2D(512, kernel_size=(3,3), activation='relu', padding='same'))
age_model_2.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
age_model_2.add(MaxPooling2D(pool_size=(2,2)))
age_model_2.add(Dropout(0.4))
age_model_2.add(BatchNormalization())

# Flatten and dense layers
age_model_2.add(Flatten())
age_model_2.add(Dense(512, activation='relu'))
age_model_2.add(Dropout(0.3))
age_model_2.add(Dense(256, activation='relu'))
age_model_2.add(Dropout(0.3))
age_model_2.add(Dense(128, activation='relu'))
age_model_2.add(Dropout(0.3))
age_model_2.add(Dense(1, activation='linear'))

age_model_2.compile(optimizer='adam', loss='mean_absolute_error')

age_model_2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 46, 46, 64)        640
#
#  max_pooling2d_7 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 23, 23, 64)       256
#  hNormalization)
#
#  conv2d_10 (Conv2D)          (None, 23, 23, 128)       73856
#
#  conv2d_11 (Conv2D)          (None, 21, 21, 128)       147584
#
#  max_pooling2d_8 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  dropout_5 (Dropout)         (None, 10, 10, 128)       0
#
#  batch_normalization_5 (Batc  (None, 10, 10, 128)      512
#  hNormalization)
#
#  conv2d_12 (Conv2D)          (None, 10, 10, 256)       295168
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 256)         590080
#
#  max_pooling2d_9 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  dropout_6 (Dropout)         (None, 4, 4, 256)         0
#
#  batch_normalization_6 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  conv2d_14 (Conv2D)          (None, 4, 4, 512)         1180160
#
#  conv2d_15 (Conv2D)          (None, 2, 2, 512)         2359808
#
#  max_pooling2d_10 (MaxPoolin  (None, 1, 1, 512)        0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 1, 1, 512)         0
#
#  batch_normalization_7 (Batc  (None, 1, 1, 512)        2048
#  hNormalization)
#
#  flatten_2 (Flatten)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 512)               262656
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_7 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 5,078,145
# Trainable params: 5,076,225
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
# Callbacks for age model
callbacks = [EarlyStopping(patience=10, 
                               min_delta=0.001,
                               restore_best_weights=True),
             ReduceLROnPlateau(patience = 2,
                               verbose=1,
                               factor=0.5,
                               min_lr = 0.0001)]

# %%
history = age_model_2.fit(X_train, y_train, 
                        epochs=35,
                        batch_size=64,
                        callbacks=callbacks,
                        validation_data=(X_test, y_test))
# Out:
# Epoch 1/35
# 297/297 [==============================] - 7s 18ms/step - loss: 12.6713 - val_loss: 43.3221 - lr: 0.0010
# Epoch 2/35
# 297/297 [==============================] - 5s 18ms/step - loss: 9.6748 - val_loss: 17.7841 - lr: 0.0010
# Epoch 3/35
# 297/297 [==============================] - 5s 18ms/step - loss: 9.1650 - val_loss: 18.2306 - lr: 0.0010
# Epoch 4/35
# 296/297 [============================>.] - ETA: 0s - loss: 8.7721
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 297/297 [==============================] - 5s 18ms/step - loss: 8.7737 - val_loss: 19.6365 - lr: 0.0010
# Epoch 5/35
# 297/297 [==============================] - 5s 17ms/step - loss: 7.9319 - val_loss: 11.6843 - lr: 5.0000e-04
# Epoch 6/35
# 297/297 [==============================] - 5s 17ms/step - loss: 7.6469 - val_loss: 10.4776 - lr: 5.0000e-04
# Epoch 7/35
# 297/297 [==============================] - 5s 18ms/step - loss: 7.4254 - val_loss: 10.7701 - lr: 5.0000e-04
# Epoch 8/35
# 297/297 [==============================] - ETA: 0s - loss: 7.4042
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 297/297 [==============================] - 5s 18ms/step - loss: 7.4042 - val_loss: 10.9562 - lr: 5.0000e-04
# Epoch 9/35
# 297/297 [==============================] - 5s 18ms/step - loss: 6.9271 - val_loss: 11.7802 - lr: 2.5000e-04
# Epoch 10/35
# 297/297 [==============================] - 5s 17ms/step - loss: 6.7660 - val_loss: 8.0360 - lr: 2.5000e-04
# Epoch 11/35
# 297/297 [==============================] - 5s 17ms/step - loss: 6.5993 - val_loss: 11.5760 - lr: 2.5000e-04
# Epoch 12/35
# 296/297 [============================>.] - ETA: 0s - loss: 6.4963
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 297/297 [==============================] - 5s 17ms/step - loss: 6.5002 - val_loss: 9.9159 - lr: 2.5000e-04
# Epoch 13/35
# 297/297 [==============================] - 5s 18ms/step - loss: 6.2676 - val_loss: 7.1617 - lr: 1.2500e-04
# Epoch 14/35
# 297/297 [==============================] - 5s 18ms/step - loss: 6.1546 - val_loss: 7.1483 - lr: 1.2500e-04
# Epoch 15/35
# 297/297 [==============================] - 5s 18ms/step - loss: 6.1189 - val_loss: 6.9789 - lr: 1.2500e-04
# Epoch 16/35
# 297/297 [==============================] - 5s 18ms/step - loss: 6.0230 - val_loss: 7.1726 - lr: 1.2500e-04
# Epoch 17/35
# 295/297 [============================>.] - ETA: 0s - loss: 5.9062
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0001.
# 297/297 [==============================] - 5s 18ms/step - loss: 5.9049 - val_loss: 7.5206 - lr: 1.2500e-04
# Epoch 18/35
# 297/297 [==============================] - 5s 17ms/step - loss: 5.8220 - val_loss: 7.0157 - lr: 1.0000e-04
# Epoch 19/35
# 297/297 [==============================] - 5s 17ms/step - loss: 5.7787 - val_loss: 7.5964 - lr: 1.0000e-04
# Epoch 20/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.7269 - val_loss: 7.1747 - lr: 1.0000e-04
# Epoch 21/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.6830 - val_loss: 6.7179 - lr: 1.0000e-04
# Epoch 22/35
# 297/297 [==============================] - 5s 17ms/step - loss: 5.6820 - val_loss: 8.3185 - lr: 1.0000e-04
# Epoch 23/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.5631 - val_loss: 6.9693 - lr: 1.0000e-04
# Epoch 24/35
# 297/297 [==============================] - 5s 17ms/step - loss: 5.5825 - val_loss: 6.9873 - lr: 1.0000e-04
# Epoch 25/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.5014 - val_loss: 8.1358 - lr: 1.0000e-04
# Epoch 26/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.4895 - val_loss: 6.5501 - lr: 1.0000e-04
# Epoch 27/35
# 297/297 [==============================] - 5s 17ms/step - loss: 5.4864 - val_loss: 6.8630 - lr: 1.0000e-04
# Epoch 28/35
# 297/297 [==============================] - 5s 17ms/step - loss: 5.3851 - val_loss: 7.6063 - lr: 1.0000e-04
# Epoch 29/35
# 297/297 [==============================] - 5s 17ms/step - loss: 5.3394 - val_loss: 8.0982 - lr: 1.0000e-04
# Epoch 30/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.3330 - val_loss: 6.6555 - lr: 1.0000e-04
# Epoch 31/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.3404 - val_loss: 6.5229 - lr: 1.0000e-04
# Epoch 32/35
# 297/297 [==============================] - 6s 19ms/step - loss: 5.2501 - val_loss: 9.6705 - lr: 1.0000e-04
# Epoch 33/35
# 297/297 [==============================] - 5s 17ms/step - loss: 5.2881 - val_loss: 8.9555 - lr: 1.0000e-04
# Epoch 34/35
# 297/297 [==============================] - 5s 17ms/step - loss: 5.2232 - val_loss: 6.5061 - lr: 1.0000e-04
# Epoch 35/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.2286 - val_loss: 7.6713 - lr: 1.0000e-04

# %%
pd.DataFrame(history.history).plot();

# %%
from sklearn.metrics import r2_score

# Make predictions 
y_pred = age_model_2.predict(X_test)

# calculate R2 score
r2 = r2_score(y_test, y_pred)

print("R2 score: {:.3f}".format(r2))
# Out:
# 149/149 [==============================] - 1s 4ms/step
# R2 score: 0.740

# %% [markdown]
# # 3. Model with adjusted Flatten layer

# %%
age_model_3 = Sequential()

age_model_3.add(Conv2D(64, kernel_size=(3,3), input_shape=input_shape, activation='relu', padding='same'))
age_model_3.add(MaxPooling2D(pool_size=(2,2)))
age_model_3.add(BatchNormalization())

age_model_3.add(Conv2D(128, kernel_size=(3,3), activation='relu', padding='same'))
age_model_3.add(Conv2D(128, kernel_size=(3,3), activation='relu', padding='same'))
age_model_3.add(MaxPooling2D(pool_size=(2,2)))
age_model_3.add(Dropout(0.3))
age_model_3.add(BatchNormalization())

age_model_3.add(Conv2D(256, kernel_size=(3,3), activation='relu', padding='same'))
age_model_3.add(Conv2D(256, kernel_size=(3,3), activation='relu', padding='same'))
age_model_3.add(MaxPooling2D(pool_size=(2,2)))
age_model_3.add(Dropout(0.4))
age_model_3.add(BatchNormalization())

age_model_3.add(Conv2D(512, kernel_size=(3,3), activation='relu', padding='same'))
age_model_3.add(MaxPooling2D(pool_size=(2,2)))
age_model_3.add(Dropout(0.5))
age_model_3.add(BatchNormalization())

age_model_3.add(Flatten())
age_model_3.add(Dense(512, activation='relu'))
age_model_3.add(Dropout(0.4))
age_model_3.add(Dense(128, activation='relu'))
age_model_3.add(Dropout(0.3))
age_model_3.add(Dense(1))

age_model_3.compile(optimizer='adam', loss='mean_absolute_error')

age_model_3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 48, 48, 64)        640
#
#  max_pooling2d_11 (MaxPoolin  (None, 24, 24, 64)       0
#  g2D)
#
#  batch_normalization_8 (Batc  (None, 24, 24, 64)       256
#  hNormalization)
#
#  conv2d_17 (Conv2D)          (None, 24, 24, 128)       73856
#
#  conv2d_18 (Conv2D)          (None, 24, 24, 128)       147584
#
#  max_pooling2d_12 (MaxPoolin  (None, 12, 12, 128)      0
#  g2D)
#
#  dropout_11 (Dropout)        (None, 12, 12, 128)       0
#
#  batch_normalization_9 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  conv2d_19 (Conv2D)          (None, 12, 12, 256)       295168
#
#  conv2d_20 (Conv2D)          (None, 12, 12, 256)       590080
#
#  max_pooling2d_13 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 6, 6, 256)         0
#
#  batch_normalization_10 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv2d_21 (Conv2D)          (None, 6, 6, 512)         1180160
#
#  max_pooling2d_14 (MaxPoolin  (None, 3, 3, 512)        0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 3, 3, 512)         0
#
#  batch_normalization_11 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  flatten_3 (Flatten)         (None, 4608)              0
#
#  dense_8 (Dense)             (None, 512)               2359808
#
#  dropout_14 (Dropout)        (None, 512)               0
#
#  dense_9 (Dense)             (None, 128)               65664
#
#  dropout_15 (Dropout)        (None, 128)               0
#
#  dense_10 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 4,716,929
# Trainable params: 4,715,009
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
# Callbacks for age model
callbacks = [EarlyStopping(patience=10, 
                               min_delta=0.001,
                               restore_best_weights=True),
             ReduceLROnPlateau(patience = 2,
                               verbose=1,
                               factor=0.5,
                               min_lr = 0.0001)]

# %%
history = age_model_3.fit(X_train, y_train, 
                        epochs=35,
                        batch_size=64,
                        callbacks=callbacks,
                        validation_data=(X_test, y_test))
# Out:
# Epoch 1/35
# 297/297 [==============================] - 7s 19ms/step - loss: 11.9663 - val_loss: 44.3127 - lr: 0.0010
# Epoch 2/35
# 297/297 [==============================] - 5s 18ms/step - loss: 9.7407 - val_loss: 44.4527 - lr: 0.0010
# Epoch 3/35
# 297/297 [==============================] - 5s 17ms/step - loss: 8.9213 - val_loss: 31.3010 - lr: 0.0010
# Epoch 4/35
# 297/297 [==============================] - 5s 17ms/step - loss: 8.6317 - val_loss: 12.2171 - lr: 0.0010
# Epoch 5/35
# 297/297 [==============================] - 5s 18ms/step - loss: 8.1083 - val_loss: 9.3292 - lr: 0.0010
# Epoch 6/35
# 297/297 [==============================] - 5s 17ms/step - loss: 7.9216 - val_loss: 12.3344 - lr: 0.0010
# Epoch 7/35
# 297/297 [==============================] - ETA: 0s - loss: 7.6568
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 297/297 [==============================] - 5s 18ms/step - loss: 7.6568 - val_loss: 11.0289 - lr: 0.0010
# Epoch 8/35
# 297/297 [==============================] - 5s 18ms/step - loss: 7.0677 - val_loss: 16.3350 - lr: 5.0000e-04
# Epoch 9/35
# 296/297 [============================>.] - ETA: 0s - loss: 6.8263
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 297/297 [==============================] - 5s 17ms/step - loss: 6.8272 - val_loss: 13.1198 - lr: 5.0000e-04
# Epoch 10/35
# 297/297 [==============================] - 5s 18ms/step - loss: 6.5174 - val_loss: 7.5576 - lr: 2.5000e-04
# Epoch 11/35
# 297/297 [==============================] - 5s 18ms/step - loss: 6.3393 - val_loss: 6.1728 - lr: 2.5000e-04
# Epoch 12/35
# 297/297 [==============================] - 5s 17ms/step - loss: 6.3098 - val_loss: 8.5843 - lr: 2.5000e-04
# Epoch 13/35
# 297/297 [==============================] - ETA: 0s - loss: 6.1598
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 297/297 [==============================] - 5s 18ms/step - loss: 6.1598 - val_loss: 7.8735 - lr: 2.5000e-04
# Epoch 14/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.9375 - val_loss: 10.9905 - lr: 1.2500e-04
# Epoch 15/35
# 297/297 [==============================] - 5s 17ms/step - loss: 5.8345 - val_loss: 6.1554 - lr: 1.2500e-04
# Epoch 16/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.7626 - val_loss: 6.7209 - lr: 1.2500e-04
# Epoch 17/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.7674 - val_loss: 6.0086 - lr: 1.2500e-04
# Epoch 18/35
# 297/297 [==============================] - 5s 17ms/step - loss: 5.6777 - val_loss: 8.0711 - lr: 1.2500e-04
# Epoch 19/35
# 294/297 [============================>.] - ETA: 0s - loss: 5.6278
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001.
# 297/297 [==============================] - 5s 18ms/step - loss: 5.6295 - val_loss: 6.1842 - lr: 1.2500e-04
# Epoch 20/35
# 297/297 [==============================] - 5s 17ms/step - loss: 5.5406 - val_loss: 5.8122 - lr: 1.0000e-04
# Epoch 21/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.4946 - val_loss: 7.5352 - lr: 1.0000e-04
# Epoch 22/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.4929 - val_loss: 5.7629 - lr: 1.0000e-04
# Epoch 23/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.4249 - val_loss: 5.9389 - lr: 1.0000e-04
# Epoch 24/35
# 297/297 [==============================] - 5s 17ms/step - loss: 5.3629 - val_loss: 5.7280 - lr: 1.0000e-04
# Epoch 25/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.3640 - val_loss: 5.7906 - lr: 1.0000e-04
# Epoch 26/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.2764 - val_loss: 5.7018 - lr: 1.0000e-04
# Epoch 27/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.3103 - val_loss: 7.4743 - lr: 1.0000e-04
# Epoch 28/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.2542 - val_loss: 5.7831 - lr: 1.0000e-04
# Epoch 29/35
# 297/297 [==============================] - 5s 17ms/step - loss: 5.1973 - val_loss: 6.7055 - lr: 1.0000e-04
# Epoch 30/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.1649 - val_loss: 6.0315 - lr: 1.0000e-04
# Epoch 31/35
# 297/297 [==============================] - 5s 17ms/step - loss: 5.0918 - val_loss: 5.9359 - lr: 1.0000e-04
# Epoch 32/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.0645 - val_loss: 5.9305 - lr: 1.0000e-04
# Epoch 33/35
# 297/297 [==============================] - 5s 18ms/step - loss: 5.0987 - val_loss: 8.5127 - lr: 1.0000e-04
# Epoch 34/35
# 297/297 [==============================] - 5s 17ms/step - loss: 4.9636 - val_loss: 5.8221 - lr: 1.0000e-04
# Epoch 35/35
# 297/297 [==============================] - 5s 18ms/step - loss: 4.9858 - val_loss: 5.6183 - lr: 1.0000e-04

# %%
pd.DataFrame(history.history).plot();

# %%
from sklearn.metrics import r2_score

# Make predictions 
y_pred = age_model_3.predict(X_test)

# calculate R2 score
r2 = r2_score(y_test, y_pred)

print("R2 score: {:.3f}".format(r2))
# Out:
# 149/149 [==============================] - 1s 3ms/step
# R2 score: 0.842

# %%
age_model_3.save('/kaggle/working/age_model_3.h5')
